# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # All the table insertions are done manually using mysql workbench

# %% [markdown]
# <h4>From 3.1 to 3.8.2 are documented in a word document - phase3_sql_doc.docx

# %% [markdown]
# 3.8.3	Store the above data (the result of 3.2) in DataFrame and analyze districts that appear 3 or more than 3 years and print the corresponding state/UT, district, murders, and year in descending order.

# %%
engine = create_engine("mysql+mysqlconnector://root:Lee123*9@localhost:3306/crimes")

# %%
df = pd.read_sql("SELECT * FROM crimes_district_wise", engine)

# %%
df
# Out:
#            StateOrUt       district   years  murder  AttemptToMurder  rape
# 0     ANDHRA PRADESH       ADILABAD  2001.0   101.0             60.0  50.0
# 1     ANDHRA PRADESH      ANANTAPUR  2001.0   151.0            125.0  23.0
# 2     ANDHRA PRADESH       CHITTOOR  2001.0   101.0             57.0  27.0
# 3     ANDHRA PRADESH       CUDDAPAH  2001.0    80.0             53.0  20.0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001.0    82.0             67.0  23.0
# ...              ...            ...     ...     ...              ...   ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012.0     0.0              0.0   0.0
# 9013     LAKSHADWEEP          TOTAL  2012.0     0.0              0.0   0.0
# 9014      PUDUCHERRY       KARAIKAL  2012.0     5.0              6.0   6.0
# 9015      PUDUCHERRY     PUDUCHERRY  2012.0    24.0             21.0   7.0
# 9016      PUDUCHERRY          TOTAL  2012.0    29.0             27.0  13.0
#
# [9017 rows x 6 columns]

# %%
query = """select stateorut, district, murder, years from (select stateorut, district, murder, years,  

row_number() over  

(partition by stateorut,years order by murder desc) rownum 

from crimes_district_wise where district<>'TOTAL') tab 

where tab.rownum=1;"""

# %%
dfx = pd.read_sql(query, engine)

# %%
dfx['years'] = dfx['years'].astype(int)

# %%
dfx
# Out:
#          stateorut           district  murder  years
# 0    A & N ISLANDS            ANDAMAN    13.0   2001
# 1    A & N ISLANDS            ANDAMAN    14.0   2002
# 2    A & N ISLANDS            ANDAMAN    16.0   2003
# 3    A & N ISLANDS            ANDAMAN    13.0   2004
# 4    A & N ISLANDS            ANDAMAN    14.0   2005
# ..             ...                ...     ...    ...
# 415    WEST BENGAL  24 PARGANAS SOUTH   239.0   2008
# 416    WEST BENGAL  24 PARGANAS NORTH   229.0   2009
# 417    WEST BENGAL   PASCHIM MIDNAPUR   268.0   2010
# 418    WEST BENGAL  24 PARGANAS SOUTH   247.0   2011
# 419    WEST BENGAL  24 PARGANAS SOUTH   224.0   2012
#
# [420 rows x 4 columns]

# %%
grps = dfx.groupby(['stateorut','years'])

# %%
dic = dict(dfx['district'].value_counts()>=3)
filtered_dict = {k:v for (k,v) in dic.items() if v==True}

# %%
lis = list(filtered_dict.keys())

# %%
dfxgt3 = dfx[dfx['district'].isin(lis)]

# %%
len(dfxgt3)
# Out:
# 364

# %%
grps = dfxgt3.groupby(['stateorut','district'])

# %%
fig, axes = plt.subplots(54,1,figsize=(20,300))
for (ind, grp),ax in zip(grps,axes.flat):
    ax = sns.lineplot(data=grp,x='murder',y='years',ax=ax)
    ax.set_title(str(ind))
plt.tight_layout()
plt.show()
